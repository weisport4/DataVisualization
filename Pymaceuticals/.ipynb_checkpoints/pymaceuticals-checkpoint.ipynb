# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Capomulin had the greatest number of observed mouse timepoints with final tumor volume amoungst the lowest.
# - For Mouse r944 the tumer volume decreased with greater timepoint days
# - There is a high correlation between weight and tumor volume.  The r-squared is: 0.7088568047708723 as well shows a nice regression as the closer to 1.0 the better the regression.
#
# -

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import seaborn as sns
import numpy as np

#Modelling libraries
from scipy.stats import linregress
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame, left join
df = pd.merge(study_results, mouse_metadata, on="Mouse ID", how="left")

# %%
# Checking the number of mice.
print(mouse_metadata.shape)
mouse_metadata.head()
df["Mouse ID"].nunique()
# Out:
# (249, 5)
# 249

# %%
print(study_results.shape)
study_results.head()
# Out:
# (1893, 4)
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
# Display the data table for preview
df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
#review the nulls and data types
print(df.shape)
df.info()
# Out:
# (1893, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1893 entries, 0 to 1892
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Mouse ID            1893 non-null   object
#  1   Timepoint           1893 non-null   int64
#  2   Tumor Volume (mm3)  1893 non-null   float64
#  3   Metastatic Sites    1893 non-null   int64
#  4   Drug Regimen        1893 non-null   object
#  5   Sex                 1893 non-null   object
#  6   Age_months          1893 non-null   int64
#  7   Weight (g)          1893 non-null   int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 118.4+ KB

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
# Groupby Mouse ID, Timepoint
df.groupby(["Mouse ID", "Timepoint"]).size().sort_values(ascending=False).head(10)
# Out:
# Mouse ID  Timepoint
# g989      20           2
#           15           2
#           10           2
#           5            2
#           0            2
# a203      0            1
# q633      0            1
# q610      20           1
#           25           1
#           30           1
# dtype: int64

# %%
# Optional: Get all the data for the duplicate mouse ID. 
mask = df["Mouse ID"] == "g989"
df.loc[mask]
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a Mask = to the duplicate Mouse Id  for the drop
# Create a clean DataFrame name clean_df by dropping the duplicate mouse by its ID using drop=True to drop the duplicate
mask = df["Mouse ID"] != "g989"
clean_df = df.loc[mask].reset_index(drop=True)
clean_df.shape
# Out:
# (1880, 8)

# %%
# Checking the number of mice in the clean DataFrame. The result shows it dropped the duplicate.
clean_df["Mouse ID"].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen (groupby regimen)
# Use mean, median, sem function 

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

tumor_mean = clean_df.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].mean()
tumor_median = clean_df.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].median()
tumor_variance = clean_df.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].var()
tumor_std = clean_df.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].std()
tumor_sem = clean_df.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].sem()

data = {
    "Mean Tumor Volume": tumor_mean,
    "Median Tumor Volume": tumor_median,
    "Tumor Volume Variance": tumor_variance,
    "Tumor Volume Std. Dev.": tumor_std,
    "Tumor Volume Std. Err.": tumor_sem
}

leaderboard = pd.DataFrame(data).reset_index()
leaderboard
# Out:
#   Drug Regimen  Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# 0    Capomulin          40.675741            41.557809              24.947764
# 1     Ceftamin          52.591172            51.776157              39.290177
# 2    Infubinol          52.884795            51.820584              43.128684
# 3     Ketapril          55.235638            53.698743              68.553577
# 4     Naftisol          54.331565            52.509285              66.173479
# 5      Placebo          54.033581            52.288934              61.168083
# 6     Propriva          52.320930            50.446266              43.852013
# 7     Ramicane          40.216745            40.673236              23.486704
# 8     Stelasyn          54.233149            52.431737              59.450562
# 9    Zoniferol          53.236507            51.818479              48.533355
#
#    Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# 0                4.994774                0.329346
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line

cols_agg = {
    "Tumor Volume (mm3)": ["mean", "median", "var", "std", "sem"]
}
leaderboard2 = clean_df.groupby(["Drug Regimen"]).agg(cols_agg).reset_index()
leaderboard2
# Out:
#   Drug Regimen Tumor Volume (mm3)
#                              mean     median        var       std       sem
# 0    Capomulin          40.675741  41.557809  24.947764  4.994774  0.329346
# 1     Ceftamin          52.591172  51.776157  39.290177  6.268188  0.469821
# 2    Infubinol          52.884795  51.820584  43.128684  6.567243  0.492236
# 3     Ketapril          55.235638  53.698743  68.553577  8.279709  0.603860
# 4     Naftisol          54.331565  52.509285  66.173479  8.134708  0.596466
# 5      Placebo          54.033581  52.288934  61.168083  7.821003  0.581331
# 6     Propriva          52.320930  50.446266  43.852013  6.622085  0.544332
# 7     Ramicane          40.216745  40.673236  23.486704  4.846308  0.320955
# 8     Stelasyn          54.233149  52.431737  59.450562  7.710419  0.573111
# 9    Zoniferol          53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
clean_df["Drug Regimen"].value_counts().sort_values().plot(kind="bar", title="Drug Regimen Totals", color="purple")
plt.ylabel("# of Observed Mouse Timepoints")
plt.xlabel("Drug Regimen")
plt.savefig("pandasbar.png")
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pyplot
data = clean_df["Drug Regimen"].value_counts()
x = list(data.index)
y = list(data.values)
drug = clean_df["Drug Regimen"]
# Step 2: Make the canvas
plt.figure(figsize=(12, 6))

# Step 3: Make the plot
plt.bar(x, y, color="purple", align="center")

# Step 4: Customizations
plt.title("Drug Regimen Totals\n", fontsize=14)
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
#plt.axis("equal")

# Step 5: Save/Show
plt.savefig("pybar.png")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
data=clean_df["Sex"].value_counts()

# Pandas Plot
# make the plot
data.plot(kind='pie', subplots=True, figsize=(8, 8), title="Title",)

# show the plot
plt.savefig("pandaspie.png")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
# Step 1: Get the data
data = clean_df["Sex"].value_counts()
x = list(data.index)
y = list(data.values)
colors = ["blue","orange"]
gender = ["Male", "Female"]
# Step 2: Make the canvas
plt.figure(figsize=(8, 6))

# Step 3: Make the plot
plt.pie(y, explode=explode, labels=gender, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=90)

# Step 4: Customizations
plt.title("Sex\n", fontweight="bold", fontsize=16)
plt.axis("equal")

# Step 5: Save/Show
plt.savefig("pyplot.png")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
# GET DATA
clean_df2 = clean_df.groupby("Mouse ID").Timepoint.max().reset_index()
sub = clean_df.loc[:, ["Mouse ID", "Timepoint", "Drug Regimen", "Tumor Volume (mm3)", "Sex"]]

clean_df2 = pd.merge(clean_df2, sub, on=["Mouse ID", "Timepoint"])

# overwrite
mask = clean_df2["Drug Regimen"].isin(["Capomulin", "Ramicane", "Infubinol", "Ceftamin"])
clean_df2 = clean_df2.loc[mask].reset_index(drop=True) # dropping rows

sns.boxplot(data=clean_df2, x="Drug Regimen", y="Tumor Volume (mm3)")
plt.title("Final Tumor Volume per Drug")
plt.savefig("boxplot.png")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
clean_df.loc[clean_df["Drug Regimen"] == "Capomulin"]

mouse = "r944"

data = clean_df.loc[clean_df["Mouse ID"] == mouse]

# Step 1: Get the data
# x_axis, points_F, points_C
timepoint = data["Timepoint"]
volume = data["Tumor Volume (mm3)"]

# Step 2: Initialize the canvas
plt.figure(figsize=(10, 4))

# Step 3: Vanilla graph (aka a BLAND graph) or a skeleton graph
plt.plot(timepoint, volume, color="purple", linewidth=2, marker="o", markersize=10)

# Step 4: Customize the graph
# LABEL X/Y Axis (UNITS when appropriate)
# TITLE
# Color - NO DEFAULT COLORS
# Optional: Line Thickness, markers, legend, gridlines
plt.xlabel("Timepoint (days)", fontsize=12, fontstyle="italic")
plt.ylabel("Tumor Volume (mm3)", fontsize=12, fontstyle="italic")
plt.title(f"Tumor Volume vs Timepoint for {mouse}", fontsize=16, fontweight="bold")

# set limits (optional...)
# plt.xlim(-5, 125)
# plt.ylim(0, 100)

# legend and grid
plt.grid(color="lightgrey", linestyle="--", alpha=0.5)

# Step 5: Show/Save the Graph
plt.savefig("linegraph.png")
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
data = clean_df.loc[clean_df["Drug Regimen"] == "Capomulin"]

# this was hard
clean_df3 = data.groupby("Mouse ID").agg({"Weight (g)": "mean", "Tumor Volume (mm3)": "mean"}).reset_index()

weight = clean_df3["Weight (g)"]
volume = clean_df3["Tumor Volume (mm3)"]

# Step 2: Make the canvas
plt.figure(figsize=(10, 6))

# Step 3: Make the basic plot
plt.scatter(weight, volume, facecolor="purple", edgecolor="black", s=150)

# Step 4: Customizations
plt.xlabel("Weight (g)", fontsize=12, fontstyle="italic")
plt.ylabel("Average Tumor Volume (mm3)", fontsize=12, fontstyle="italic")
plt.title("Weight vs Tumor for Capomulin", fontweight="bold", fontsize=16)

# plt.xlim(10, 27)
# plt.ylim(0, 650)

plt.grid(color="lightgrey", linestyle = "--", alpha=0.5)

# Step 5: Show/Save the graph
plt.savefig("scatterplot.png")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

corrs = clean_df.corr(numeric_only = True)
corrs
# Out:
#                     Weight (g)  Tumor Volume (mm3)
# Weight (g)            1.000000            0.841936
# Tumor Volume (mm3)    0.841936            1.000000

# %%
# USING LINREGRESS
x_data = clean_df3["Weight (g)"]
y_data = clean_df3["Tumor Volume (mm3)"]

# makes the line of best fit
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_data, y_data)
regress_values = x_data * slope + intercept # calculate the predictions
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)

# make the plot
# Step 2: Make the canvas
plt.figure(figsize=(10, 6))

# Step 3: Make the basic plot
plt.scatter(x_data, y_data, facecolor="purple", edgecolor="black", s=100)
plt.plot(x_data, regress_values, "r-")

# Step 4: Customizations
plt.xlabel("Weight (g)", fontsize=12, fontstyle="italic")
plt.ylabel("Tumor Volume (mm3)", fontsize=12, fontstyle="italic")
plt.title("Weight vs Tumor for Capomulin", fontweight="bold", fontsize=16)
plt.grid(color="grey", linestyle = "--", alpha=0.5)

plt.annotate(line_eq,(22, 36),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
plt.savefig("linregress.png")
plt.show()
# Out:
# y = 0.95x + 21.55
# The r-squared is: 0.7088568047708723
